# %%
import os
import torch
import json
import copy
import numpy as np
from torchvision import datasets, transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import logging
import random
import datetime as dt

# %%
_cfg = {
    'VGG11': [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG13': [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
    'VGG19': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512, 512, 512, 'M', 512, 512, 512, 512, 'M'],
}


def _make_layers(cfg):
    layers = []
    in_channels = 3
    for layer_cfg in cfg:
        if layer_cfg == 'M':
            layers.append(nn.MaxPool2d(kernel_size=2, stride=2))
        else:
            layers.append(nn.Conv2d(in_channels=in_channels,
                                    out_channels=layer_cfg,
                                    kernel_size=3,
                                    stride=1,
                                    padding=1,
                                    bias=True))
            layers.append(nn.BatchNorm2d(num_features=layer_cfg))
            layers.append(nn.ReLU(inplace=True))
            in_channels = layer_cfg
    return nn.Sequential(*layers)


class _VGG(nn.Module):
    """
    VGG module for 3x32x32 input, 10 classes
    """

    def __init__(self, name='VGG11'):
        super(_VGG, self).__init__()
        cfg = _cfg[name]
        self.layers = _make_layers(cfg)
        flatten_features = 512
        self.fc1 = nn.Linear(flatten_features, 10)

    def forward(self, x):
        y = self.layers(x)
        y = y.view(y.size(0), -1)
        y = self.fc1(y)
        return y


def VGG11():
    return _VGG('VGG11')

# %%
# from google.colab import files
# files.upload()

# import model as mdl

# %%
torch.set_num_threads(4)
# device = "cpu"
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
batch_size = 256 # batch for one node

# %%
def train_model(model, train_loader, optimizer, criterion, epoch):
    """
    model (torch.nn.module): The model created to train
    train_loader (pytorch data loader): Training data loader
    optimizer (optimizer.*): A instance of some sort of optimizer, usually SGD
    criterion (nn.CrossEntropyLoss) : Loss function used to train the network
    epoch (int): Current epoch number
    """
    epoch_startTime = dt.datetime.now()
    running_loss = 0.0
    # remember to exit the train loop at   end of the epoch
    for batch_idx, (data, target) in enumerate(train_loader):
        # Your code goes here!

        batch_startTime = dt.datetime.now()
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        outputs = model(data)
        loss = criterion(outputs, target)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        msg_iteration = 20
        if batch_idx % msg_iteration == msg_iteration-1:    # print every $msg_iteration mini-batches
            batch_endTime = dt.datetime.now()
            batch_time = "{:.2f}".format((batch_endTime - batch_startTime).total_seconds())
            print(f'epoch : {epoch + 1} batch_no:{batch_idx + 1:5d} MeanLoss_last_{msg_iteration}_batches: {running_loss / msg_iteration:.3f} current_batch_time: {batch_time} secs')
            running_loss = 0.0

        # break
    epoch_endTime = dt.datetime.now()
    epoch_time = "{:.2f}".format((epoch_endTime - epoch_startTime).total_seconds())
    print("Time taken for epoch : ",epoch + 1," = ",epoch_time," secs" )
    ckp = model.state_dict()
    PATH = "checkpoint.pt"
    torch.save(ckp, PATH)
    print(f"Epoch {epoch + 1} | Training checkpoint saved at {PATH}")

    return None

# %%
def test_model(model, test_loader, criterion):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(test_loader):
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += criterion(output, target)
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader)
    print('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, correct, len(test_loader.dataset),
            100. * correct / len(test_loader.dataset)))

# %%
def main():
    normalize = transforms.Normalize(mean=[x/255.0 for x in [125.3, 123.0, 113.9]],
                                std=[x/255.0 for x in [63.0, 62.1, 66.7]])
    transform_train = transforms.Compose([
            transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
            ])

    transform_test = transforms.Compose([
            transforms.ToTensor(),
            normalize])
    training_set = datasets.CIFAR10(root="./data", train=True,
                                                download=True, transform=transform_train)
    train_loader = torch.utils.data.DataLoader(training_set,
                                                    num_workers=2,
                                                    batch_size=batch_size,
                                                    sampler=None,
                                                    shuffle=True,
                                                    pin_memory=True)
    test_set = datasets.CIFAR10(root="./data", train=False,
                                download=True, transform=transform_test)

    test_loader = torch.utils.data.DataLoader(test_set,
                                              num_workers=2,
                                              batch_size=batch_size,
                                              shuffle=False,
                                              pin_memory=True)
    training_criterion = torch.nn.CrossEntropyLoss().to(device)

    model = VGG11()
    model.to(device)
    optimizer = optim.SGD(model.parameters(), lr=0.001,
                          momentum=0.9, weight_decay=0.0001)
    # running training for one epoch
    for epoch in range(30):
        train_model(model, train_loader, optimizer, training_criterion, epoch)
        test_model(model, test_loader, training_criterion)

# %%
if __name__ == "__main__":
    main()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 45689962.39it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# epoch : 1 batch_no:   20 MeanLoss_last_20_batches: 2.092 current_batch_time: 0.05 secs
# epoch : 1 batch_no:   40 MeanLoss_last_20_batches: 1.743 current_batch_time: 0.05 secs
# epoch : 1 batch_no:   60 MeanLoss_last_20_batches: 1.560 current_batch_time: 0.05 secs
# epoch : 1 batch_no:   80 MeanLoss_last_20_batches: 1.490 current_batch_time: 0.05 secs
# epoch : 1 batch_no:  100 MeanLoss_last_20_batches: 1.399 current_batch_time: 0.05 secs
# epoch : 1 batch_no:  120 MeanLoss_last_20_batches: 1.334 current_batch_time: 0.05 secs
# epoch : 1 batch_no:  140 MeanLoss_last_20_batches: 1.309 current_batch_time: 0.05 secs
# epoch : 1 batch_no:  160 MeanLoss_last_20_batches: 1.257 current_batch_time: 0.05 secs
# epoch : 1 batch_no:  180 MeanLoss_last_20_batches: 1.226 current_batch_time: 0.04 secs
# Time taken for epoch :  1  =  30.00  secs
# Epoch 1 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 1.1641, Accuracy: 5786/10000 (58%)
#
# epoch : 2 batch_no:   20 MeanLoss_last_20_batches: 1.756 current_batch_time: 0.05 secs
# epoch : 2 batch_no:   40 MeanLoss_last_20_batches: 1.485 current_batch_time: 0.05 secs
# epoch : 2 batch_no:   60 MeanLoss_last_20_batches: 1.364 current_batch_time: 0.05 secs
# epoch : 2 batch_no:   80 MeanLoss_last_20_batches: 1.336 current_batch_time: 0.06 secs
# epoch : 2 batch_no:  100 MeanLoss_last_20_batches: 1.333 current_batch_time: 0.05 secs
# epoch : 2 batch_no:  120 MeanLoss_last_20_batches: 1.210 current_batch_time: 0.05 secs
# epoch : 2 batch_no:  140 MeanLoss_last_20_batches: 1.221 current_batch_time: 0.05 secs
# epoch : 2 batch_no:  160 MeanLoss_last_20_batches: 1.186 current_batch_time: 0.05 secs
# epoch : 2 batch_no:  180 MeanLoss_last_20_batches: 1.149 current_batch_time: 0.05 secs
# Time taken for epoch :  2  =  21.50  secs
# Epoch 2 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 1.0702, Accuracy: 6138/10000 (61%)
#
# epoch : 3 batch_no:   20 MeanLoss_last_20_batches: 1.178 current_batch_time: 0.05 secs
# epoch : 3 batch_no:   40 MeanLoss_last_20_batches: 1.095 current_batch_time: 0.04 secs
# epoch : 3 batch_no:   60 MeanLoss_last_20_batches: 1.154 current_batch_time: 0.05 secs
# epoch : 3 batch_no:   80 MeanLoss_last_20_batches: 1.140 current_batch_time: 0.05 secs
# epoch : 3 batch_no:  100 MeanLoss_last_20_batches: 1.119 current_batch_time: 0.05 secs
# epoch : 3 batch_no:  120 MeanLoss_last_20_batches: 1.043 current_batch_time: 0.05 secs
# epoch : 3 batch_no:  140 MeanLoss_last_20_batches: 1.073 current_batch_time: 0.04 secs
# epoch : 3 batch_no:  160 MeanLoss_last_20_batches: 1.024 current_batch_time: 0.05 secs
# epoch : 3 batch_no:  180 MeanLoss_last_20_batches: 1.047 current_batch_time: 0.04 secs
# Time taken for epoch :  3  =  22.49  secs
# Epoch 3 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 1.0162, Accuracy: 6412/10000 (64%)
#
# epoch : 4 batch_no:   20 MeanLoss_last_20_batches: 0.987 current_batch_time: 0.05 secs
# epoch : 4 batch_no:   40 MeanLoss_last_20_batches: 0.995 current_batch_time: 0.05 secs
# epoch : 4 batch_no:   60 MeanLoss_last_20_batches: 0.981 current_batch_time: 0.06 secs
# epoch : 4 batch_no:   80 MeanLoss_last_20_batches: 0.949 current_batch_time: 0.05 secs
# epoch : 4 batch_no:  100 MeanLoss_last_20_batches: 0.984 current_batch_time: 0.05 secs
# epoch : 4 batch_no:  120 MeanLoss_last_20_batches: 0.957 current_batch_time: 0.05 secs
# epoch : 4 batch_no:  140 MeanLoss_last_20_batches: 0.949 current_batch_time: 0.05 secs
# epoch : 4 batch_no:  160 MeanLoss_last_20_batches: 0.964 current_batch_time: 0.05 secs
# epoch : 4 batch_no:  180 MeanLoss_last_20_batches: 0.949 current_batch_time: 0.05 secs
# Time taken for epoch :  4  =  22.44  secs
# Epoch 4 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.9980, Accuracy: 6495/10000 (65%)
#
# epoch : 5 batch_no:   20 MeanLoss_last_20_batches: 0.972 current_batch_time: 0.05 secs
# epoch : 5 batch_no:   40 MeanLoss_last_20_batches: 0.937 current_batch_time: 0.05 secs
# epoch : 5 batch_no:   60 MeanLoss_last_20_batches: 0.918 current_batch_time: 0.05 secs
# epoch : 5 batch_no:   80 MeanLoss_last_20_batches: 0.884 current_batch_time: 0.04 secs
# epoch : 5 batch_no:  100 MeanLoss_last_20_batches: 0.919 current_batch_time: 0.05 secs
# epoch : 5 batch_no:  120 MeanLoss_last_20_batches: 0.885 current_batch_time: 0.05 secs
# epoch : 5 batch_no:  140 MeanLoss_last_20_batches: 0.889 current_batch_time: 0.04 secs
# epoch : 5 batch_no:  160 MeanLoss_last_20_batches: 0.868 current_batch_time: 0.05 secs
# epoch : 5 batch_no:  180 MeanLoss_last_20_batches: 0.867 current_batch_time: 0.04 secs
# Time taken for epoch :  5  =  21.41  secs
# Epoch 5 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.8845, Accuracy: 6921/10000 (69%)
#
# epoch : 6 batch_no:   20 MeanLoss_last_20_batches: 0.892 current_batch_time: 0.05 secs
# epoch : 6 batch_no:   40 MeanLoss_last_20_batches: 0.846 current_batch_time: 0.05 secs
# epoch : 6 batch_no:   60 MeanLoss_last_20_batches: 0.804 current_batch_time: 0.05 secs
# epoch : 6 batch_no:   80 MeanLoss_last_20_batches: 0.842 current_batch_time: 0.05 secs
# epoch : 6 batch_no:  100 MeanLoss_last_20_batches: 0.830 current_batch_time: 0.05 secs
# epoch : 6 batch_no:  120 MeanLoss_last_20_batches: 0.826 current_batch_time: 0.05 secs
# epoch : 6 batch_no:  140 MeanLoss_last_20_batches: 0.863 current_batch_time: 0.05 secs
# epoch : 6 batch_no:  160 MeanLoss_last_20_batches: 0.801 current_batch_time: 0.05 secs
# epoch : 6 batch_no:  180 MeanLoss_last_20_batches: 0.803 current_batch_time: 0.05 secs
# Time taken for epoch :  6  =  22.55  secs
# Epoch 6 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.8612, Accuracy: 7045/10000 (70%)
#
# epoch : 7 batch_no:   20 MeanLoss_last_20_batches: 0.856 current_batch_time: 0.05 secs
# epoch : 7 batch_no:   40 MeanLoss_last_20_batches: 0.800 current_batch_time: 0.04 secs
# epoch : 7 batch_no:   60 MeanLoss_last_20_batches: 0.728 current_batch_time: 0.05 secs
# epoch : 7 batch_no:   80 MeanLoss_last_20_batches: 0.780 current_batch_time: 0.04 secs
# epoch : 7 batch_no:  100 MeanLoss_last_20_batches: 0.787 current_batch_time: 0.04 secs
# epoch : 7 batch_no:  120 MeanLoss_last_20_batches: 0.781 current_batch_time: 0.04 secs
# epoch : 7 batch_no:  140 MeanLoss_last_20_batches: 0.747 current_batch_time: 0.04 secs
# epoch : 7 batch_no:  160 MeanLoss_last_20_batches: 0.769 current_batch_time: 0.04 secs
# epoch : 7 batch_no:  180 MeanLoss_last_20_batches: 0.736 current_batch_time: 0.05 secs
# Time taken for epoch :  7  =  23.32  secs
# Epoch 7 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.7504, Accuracy: 7356/10000 (74%)
#
# epoch : 8 batch_no:   20 MeanLoss_last_20_batches: 0.733 current_batch_time: 0.05 secs
# epoch : 8 batch_no:   40 MeanLoss_last_20_batches: 0.757 current_batch_time: 0.05 secs
# epoch : 8 batch_no:   60 MeanLoss_last_20_batches: 0.737 current_batch_time: 0.05 secs
# epoch : 8 batch_no:   80 MeanLoss_last_20_batches: 0.751 current_batch_time: 0.05 secs
# epoch : 8 batch_no:  100 MeanLoss_last_20_batches: 0.718 current_batch_time: 0.05 secs
# epoch : 8 batch_no:  120 MeanLoss_last_20_batches: 0.695 current_batch_time: 0.04 secs
# epoch : 8 batch_no:  140 MeanLoss_last_20_batches: 0.722 current_batch_time: 0.04 secs
# epoch : 8 batch_no:  160 MeanLoss_last_20_batches: 0.702 current_batch_time: 0.04 secs
# epoch : 8 batch_no:  180 MeanLoss_last_20_batches: 0.706 current_batch_time: 0.04 secs
# Time taken for epoch :  8  =  22.28  secs
# Epoch 8 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.7032, Accuracy: 7542/10000 (75%)
#
# epoch : 9 batch_no:   20 MeanLoss_last_20_batches: 0.699 current_batch_time: 0.05 secs
# epoch : 9 batch_no:   40 MeanLoss_last_20_batches: 0.685 current_batch_time: 0.04 secs
# epoch : 9 batch_no:   60 MeanLoss_last_20_batches: 0.692 current_batch_time: 0.04 secs
# epoch : 9 batch_no:   80 MeanLoss_last_20_batches: 0.672 current_batch_time: 0.05 secs
# epoch : 9 batch_no:  100 MeanLoss_last_20_batches: 0.685 current_batch_time: 0.05 secs
# epoch : 9 batch_no:  120 MeanLoss_last_20_batches: 0.727 current_batch_time: 0.04 secs
# epoch : 9 batch_no:  140 MeanLoss_last_20_batches: 0.704 current_batch_time: 0.05 secs
# epoch : 9 batch_no:  160 MeanLoss_last_20_batches: 0.662 current_batch_time: 0.05 secs
# epoch : 9 batch_no:  180 MeanLoss_last_20_batches: 0.697 current_batch_time: 0.05 secs
# Time taken for epoch :  9  =  21.70  secs
# Epoch 9 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.7140, Accuracy: 7537/10000 (75%)
#
# epoch : 10 batch_no:   20 MeanLoss_last_20_batches: 0.702 current_batch_time: 0.05 secs
# epoch : 10 batch_no:   40 MeanLoss_last_20_batches: 0.655 current_batch_time: 0.05 secs
# epoch : 10 batch_no:   60 MeanLoss_last_20_batches: 0.625 current_batch_time: 0.05 secs
# epoch : 10 batch_no:   80 MeanLoss_last_20_batches: 0.667 current_batch_time: 0.05 secs
# epoch : 10 batch_no:  100 MeanLoss_last_20_batches: 0.653 current_batch_time: 0.05 secs
# epoch : 10 batch_no:  120 MeanLoss_last_20_batches: 0.673 current_batch_time: 0.05 secs
# epoch : 10 batch_no:  140 MeanLoss_last_20_batches: 0.643 current_batch_time: 0.04 secs
# epoch : 10 batch_no:  160 MeanLoss_last_20_batches: 0.656 current_batch_time: 0.05 secs
# epoch : 10 batch_no:  180 MeanLoss_last_20_batches: 0.663 current_batch_time: 0.05 secs
# Time taken for epoch :  10  =  23.40  secs
# Epoch 10 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.6502, Accuracy: 7740/10000 (77%)
#
# epoch : 11 batch_no:   20 MeanLoss_last_20_batches: 0.628 current_batch_time: 0.05 secs
# epoch : 11 batch_no:   40 MeanLoss_last_20_batches: 0.628 current_batch_time: 0.05 secs
# epoch : 11 batch_no:   60 MeanLoss_last_20_batches: 0.631 current_batch_time: 0.05 secs
# epoch : 11 batch_no:   80 MeanLoss_last_20_batches: 0.632 current_batch_time: 0.04 secs
# epoch : 11 batch_no:  100 MeanLoss_last_20_batches: 0.625 current_batch_time: 0.05 secs
# epoch : 11 batch_no:  120 MeanLoss_last_20_batches: 0.628 current_batch_time: 0.06 secs
# epoch : 11 batch_no:  140 MeanLoss_last_20_batches: 0.616 current_batch_time: 0.05 secs
# epoch : 11 batch_no:  160 MeanLoss_last_20_batches: 0.618 current_batch_time: 0.05 secs
# epoch : 11 batch_no:  180 MeanLoss_last_20_batches: 0.632 current_batch_time: 0.04 secs
# Time taken for epoch :  11  =  23.10  secs
# Epoch 11 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.6531, Accuracy: 7732/10000 (77%)
#
# epoch : 12 batch_no:   20 MeanLoss_last_20_batches: 0.597 current_batch_time: 0.04 secs
# epoch : 12 batch_no:   40 MeanLoss_last_20_batches: 0.598 current_batch_time: 0.04 secs
# epoch : 12 batch_no:   60 MeanLoss_last_20_batches: 0.629 current_batch_time: 0.05 secs
# epoch : 12 batch_no:   80 MeanLoss_last_20_batches: 0.600 current_batch_time: 0.04 secs
# epoch : 12 batch_no:  100 MeanLoss_last_20_batches: 0.601 current_batch_time: 0.05 secs
# epoch : 12 batch_no:  120 MeanLoss_last_20_batches: 0.590 current_batch_time: 0.04 secs
# epoch : 12 batch_no:  140 MeanLoss_last_20_batches: 0.572 current_batch_time: 0.05 secs
# epoch : 12 batch_no:  160 MeanLoss_last_20_batches: 0.590 current_batch_time: 0.05 secs
# epoch : 12 batch_no:  180 MeanLoss_last_20_batches: 0.594 current_batch_time: 0.05 secs
# Time taken for epoch :  12  =  21.72  secs
# Epoch 12 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.6815, Accuracy: 7679/10000 (77%)
#
# epoch : 13 batch_no:   20 MeanLoss_last_20_batches: 0.590 current_batch_time: 0.05 secs
# epoch : 13 batch_no:   40 MeanLoss_last_20_batches: 0.560 current_batch_time: 0.05 secs
# epoch : 13 batch_no:   60 MeanLoss_last_20_batches: 0.552 current_batch_time: 0.05 secs
# epoch : 13 batch_no:   80 MeanLoss_last_20_batches: 0.589 current_batch_time: 0.04 secs
# epoch : 13 batch_no:  100 MeanLoss_last_20_batches: 0.576 current_batch_time: 0.04 secs
# epoch : 13 batch_no:  120 MeanLoss_last_20_batches: 0.550 current_batch_time: 0.05 secs
# epoch : 13 batch_no:  140 MeanLoss_last_20_batches: 0.589 current_batch_time: 0.04 secs
# epoch : 13 batch_no:  160 MeanLoss_last_20_batches: 0.582 current_batch_time: 0.04 secs
# epoch : 13 batch_no:  180 MeanLoss_last_20_batches: 0.564 current_batch_time: 0.04 secs
# Time taken for epoch :  13  =  22.57  secs
# Epoch 13 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.6227, Accuracy: 7877/10000 (79%)
#
# epoch : 14 batch_no:   20 MeanLoss_last_20_batches: 0.528 current_batch_time: 0.05 secs
# epoch : 14 batch_no:   40 MeanLoss_last_20_batches: 0.554 current_batch_time: 0.05 secs
# epoch : 14 batch_no:   60 MeanLoss_last_20_batches: 0.541 current_batch_time: 0.05 secs
# epoch : 14 batch_no:   80 MeanLoss_last_20_batches: 0.566 current_batch_time: 0.05 secs
# epoch : 14 batch_no:  100 MeanLoss_last_20_batches: 0.548 current_batch_time: 0.04 secs
# epoch : 14 batch_no:  120 MeanLoss_last_20_batches: 0.530 current_batch_time: 0.05 secs
# epoch : 14 batch_no:  140 MeanLoss_last_20_batches: 0.554 current_batch_time: 0.05 secs
# epoch : 14 batch_no:  160 MeanLoss_last_20_batches: 0.555 current_batch_time: 0.05 secs
# epoch : 14 batch_no:  180 MeanLoss_last_20_batches: 0.546 current_batch_time: 0.06 secs
# Time taken for epoch :  14  =  23.42  secs
# Epoch 14 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.6051, Accuracy: 7895/10000 (79%)
#
# epoch : 15 batch_no:   20 MeanLoss_last_20_batches: 0.522 current_batch_time: 0.05 secs
# epoch : 15 batch_no:   40 MeanLoss_last_20_batches: 0.502 current_batch_time: 0.04 secs
# epoch : 15 batch_no:   60 MeanLoss_last_20_batches: 0.549 current_batch_time: 0.05 secs
# epoch : 15 batch_no:   80 MeanLoss_last_20_batches: 0.539 current_batch_time: 0.05 secs
# epoch : 15 batch_no:  100 MeanLoss_last_20_batches: 0.527 current_batch_time: 0.04 secs
# epoch : 15 batch_no:  120 MeanLoss_last_20_batches: 0.528 current_batch_time: 0.05 secs
# epoch : 15 batch_no:  140 MeanLoss_last_20_batches: 0.553 current_batch_time: 0.05 secs
# epoch : 15 batch_no:  160 MeanLoss_last_20_batches: 0.534 current_batch_time: 0.05 secs
# epoch : 15 batch_no:  180 MeanLoss_last_20_batches: 0.534 current_batch_time: 0.04 secs
# Time taken for epoch :  15  =  24.20  secs
# Epoch 15 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.6272, Accuracy: 7828/10000 (78%)
#
# epoch : 16 batch_no:   20 MeanLoss_last_20_batches: 0.538 current_batch_time: 0.05 secs
# epoch : 16 batch_no:   40 MeanLoss_last_20_batches: 0.520 current_batch_time: 0.04 secs
# epoch : 16 batch_no:   60 MeanLoss_last_20_batches: 0.529 current_batch_time: 0.05 secs
# epoch : 16 batch_no:   80 MeanLoss_last_20_batches: 0.505 current_batch_time: 0.05 secs
# epoch : 16 batch_no:  100 MeanLoss_last_20_batches: 0.498 current_batch_time: 0.06 secs
# epoch : 16 batch_no:  120 MeanLoss_last_20_batches: 0.481 current_batch_time: 0.06 secs
# epoch : 16 batch_no:  140 MeanLoss_last_20_batches: 0.494 current_batch_time: 0.05 secs
# epoch : 16 batch_no:  160 MeanLoss_last_20_batches: 0.505 current_batch_time: 0.05 secs
# epoch : 16 batch_no:  180 MeanLoss_last_20_batches: 0.520 current_batch_time: 0.05 secs
# Time taken for epoch :  16  =  21.63  secs
# Epoch 16 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.5776, Accuracy: 7999/10000 (80%)
#
# epoch : 17 batch_no:   20 MeanLoss_last_20_batches: 0.476 current_batch_time: 0.05 secs
# epoch : 17 batch_no:   40 MeanLoss_last_20_batches: 0.485 current_batch_time: 0.05 secs
# epoch : 17 batch_no:   60 MeanLoss_last_20_batches: 0.486 current_batch_time: 0.05 secs
# epoch : 17 batch_no:   80 MeanLoss_last_20_batches: 0.469 current_batch_time: 0.05 secs
# epoch : 17 batch_no:  100 MeanLoss_last_20_batches: 0.466 current_batch_time: 0.05 secs
# epoch : 17 batch_no:  120 MeanLoss_last_20_batches: 0.491 current_batch_time: 0.04 secs
# epoch : 17 batch_no:  140 MeanLoss_last_20_batches: 0.475 current_batch_time: 0.05 secs
# epoch : 17 batch_no:  160 MeanLoss_last_20_batches: 0.500 current_batch_time: 0.04 secs
# epoch : 17 batch_no:  180 MeanLoss_last_20_batches: 0.502 current_batch_time: 0.05 secs
# Time taken for epoch :  17  =  22.94  secs
# Epoch 17 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.5707, Accuracy: 8102/10000 (81%)
#
# epoch : 18 batch_no:   20 MeanLoss_last_20_batches: 0.486 current_batch_time: 0.05 secs
# epoch : 18 batch_no:   40 MeanLoss_last_20_batches: 0.449 current_batch_time: 0.05 secs
# epoch : 18 batch_no:   60 MeanLoss_last_20_batches: 0.448 current_batch_time: 0.05 secs
# epoch : 18 batch_no:   80 MeanLoss_last_20_batches: 0.471 current_batch_time: 0.05 secs
# epoch : 18 batch_no:  100 MeanLoss_last_20_batches: 0.452 current_batch_time: 0.05 secs
# epoch : 18 batch_no:  120 MeanLoss_last_20_batches: 0.496 current_batch_time: 0.05 secs
# epoch : 18 batch_no:  140 MeanLoss_last_20_batches: 0.523 current_batch_time: 0.05 secs
# epoch : 18 batch_no:  160 MeanLoss_last_20_batches: 0.463 current_batch_time: 0.05 secs
# epoch : 18 batch_no:  180 MeanLoss_last_20_batches: 0.467 current_batch_time: 0.06 secs
# Time taken for epoch :  18  =  23.52  secs
# Epoch 18 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.5800, Accuracy: 8065/10000 (81%)
#
# epoch : 19 batch_no:   20 MeanLoss_last_20_batches: 0.456 current_batch_time: 0.05 secs
# epoch : 19 batch_no:   40 MeanLoss_last_20_batches: 0.433 current_batch_time: 0.05 secs
# epoch : 19 batch_no:   60 MeanLoss_last_20_batches: 0.453 current_batch_time: 0.05 secs
# epoch : 19 batch_no:   80 MeanLoss_last_20_batches: 0.453 current_batch_time: 0.06 secs
# epoch : 19 batch_no:  100 MeanLoss_last_20_batches: 0.462 current_batch_time: 0.05 secs
# epoch : 19 batch_no:  120 MeanLoss_last_20_batches: 0.461 current_batch_time: 0.05 secs
# epoch : 19 batch_no:  140 MeanLoss_last_20_batches: 0.453 current_batch_time: 0.05 secs
# epoch : 19 batch_no:  160 MeanLoss_last_20_batches: 0.448 current_batch_time: 0.05 secs
# epoch : 19 batch_no:  180 MeanLoss_last_20_batches: 0.459 current_batch_time: 0.05 secs
# Time taken for epoch :  19  =  21.93  secs
# Epoch 19 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.5510, Accuracy: 8175/10000 (82%)
#
# epoch : 20 batch_no:   20 MeanLoss_last_20_batches: 0.420 current_batch_time: 0.05 secs
# epoch : 20 batch_no:   40 MeanLoss_last_20_batches: 0.425 current_batch_time: 0.04 secs
# epoch : 20 batch_no:   60 MeanLoss_last_20_batches: 0.452 current_batch_time: 0.06 secs
# epoch : 20 batch_no:   80 MeanLoss_last_20_batches: 0.428 current_batch_time: 0.05 secs
# epoch : 20 batch_no:  100 MeanLoss_last_20_batches: 0.425 current_batch_time: 0.05 secs
# epoch : 20 batch_no:  120 MeanLoss_last_20_batches: 0.431 current_batch_time: 0.05 secs
# epoch : 20 batch_no:  140 MeanLoss_last_20_batches: 0.435 current_batch_time: 0.04 secs
# epoch : 20 batch_no:  160 MeanLoss_last_20_batches: 0.448 current_batch_time: 0.04 secs
# epoch : 20 batch_no:  180 MeanLoss_last_20_batches: 0.457 current_batch_time: 0.04 secs
# Time taken for epoch :  20  =  21.45  secs
# Epoch 20 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.5509, Accuracy: 8149/10000 (81%)
#
# epoch : 21 batch_no:   20 MeanLoss_last_20_batches: 0.411 current_batch_time: 0.05 secs
# epoch : 21 batch_no:   40 MeanLoss_last_20_batches: 0.414 current_batch_time: 0.05 secs
# epoch : 21 batch_no:   60 MeanLoss_last_20_batches: 0.428 current_batch_time: 0.05 secs
# epoch : 21 batch_no:   80 MeanLoss_last_20_batches: 0.418 current_batch_time: 0.04 secs
# epoch : 21 batch_no:  100 MeanLoss_last_20_batches: 0.440 current_batch_time: 0.04 secs
# epoch : 21 batch_no:  120 MeanLoss_last_20_batches: 0.406 current_batch_time: 0.05 secs
# epoch : 21 batch_no:  140 MeanLoss_last_20_batches: 0.425 current_batch_time: 0.04 secs
# epoch : 21 batch_no:  160 MeanLoss_last_20_batches: 0.417 current_batch_time: 0.05 secs
# epoch : 21 batch_no:  180 MeanLoss_last_20_batches: 0.413 current_batch_time: 0.06 secs
# Time taken for epoch :  21  =  23.35  secs
# Epoch 21 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.6097, Accuracy: 7929/10000 (79%)
#
# epoch : 22 batch_no:   20 MeanLoss_last_20_batches: 0.438 current_batch_time: 0.05 secs
# epoch : 22 batch_no:   40 MeanLoss_last_20_batches: 0.431 current_batch_time: 0.05 secs
# epoch : 22 batch_no:   60 MeanLoss_last_20_batches: 0.410 current_batch_time: 0.05 secs
# epoch : 22 batch_no:   80 MeanLoss_last_20_batches: 0.411 current_batch_time: 0.05 secs
# epoch : 22 batch_no:  100 MeanLoss_last_20_batches: 0.395 current_batch_time: 0.04 secs
# epoch : 22 batch_no:  120 MeanLoss_last_20_batches: 0.401 current_batch_time: 0.05 secs
# epoch : 22 batch_no:  140 MeanLoss_last_20_batches: 0.419 current_batch_time: 0.05 secs
# epoch : 22 batch_no:  160 MeanLoss_last_20_batches: 0.421 current_batch_time: 0.05 secs
# epoch : 22 batch_no:  180 MeanLoss_last_20_batches: 0.412 current_batch_time: 0.06 secs
# Time taken for epoch :  22  =  22.46  secs
# Epoch 22 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.5712, Accuracy: 8152/10000 (82%)
#
# epoch : 23 batch_no:   20 MeanLoss_last_20_batches: 0.387 current_batch_time: 0.05 secs
# epoch : 23 batch_no:   40 MeanLoss_last_20_batches: 0.386 current_batch_time: 0.04 secs
# epoch : 23 batch_no:   60 MeanLoss_last_20_batches: 0.405 current_batch_time: 0.05 secs
# epoch : 23 batch_no:   80 MeanLoss_last_20_batches: 0.384 current_batch_time: 0.04 secs
# epoch : 23 batch_no:  100 MeanLoss_last_20_batches: 0.409 current_batch_time: 0.04 secs
# epoch : 23 batch_no:  120 MeanLoss_last_20_batches: 0.438 current_batch_time: 0.05 secs
# epoch : 23 batch_no:  140 MeanLoss_last_20_batches: 0.395 current_batch_time: 0.05 secs
# epoch : 23 batch_no:  160 MeanLoss_last_20_batches: 0.389 current_batch_time: 0.05 secs
# epoch : 23 batch_no:  180 MeanLoss_last_20_batches: 0.390 current_batch_time: 0.04 secs
# Time taken for epoch :  23  =  21.81  secs
# Epoch 23 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.5304, Accuracy: 8208/10000 (82%)
#
# epoch : 24 batch_no:   20 MeanLoss_last_20_batches: 0.390 current_batch_time: 0.05 secs
# epoch : 24 batch_no:   40 MeanLoss_last_20_batches: 0.363 current_batch_time: 0.04 secs
# epoch : 24 batch_no:   60 MeanLoss_last_20_batches: 0.403 current_batch_time: 0.05 secs
# epoch : 24 batch_no:   80 MeanLoss_last_20_batches: 0.378 current_batch_time: 0.05 secs
# epoch : 24 batch_no:  100 MeanLoss_last_20_batches: 0.378 current_batch_time: 0.04 secs
# epoch : 24 batch_no:  120 MeanLoss_last_20_batches: 0.381 current_batch_time: 0.04 secs
# epoch : 24 batch_no:  140 MeanLoss_last_20_batches: 0.357 current_batch_time: 0.04 secs
# epoch : 24 batch_no:  160 MeanLoss_last_20_batches: 0.399 current_batch_time: 0.05 secs
# epoch : 24 batch_no:  180 MeanLoss_last_20_batches: 0.371 current_batch_time: 0.05 secs
# Time taken for epoch :  24  =  22.81  secs
# Epoch 24 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.5634, Accuracy: 8124/10000 (81%)
#
# epoch : 25 batch_no:   20 MeanLoss_last_20_batches: 0.374 current_batch_time: 0.05 secs
# epoch : 25 batch_no:   40 MeanLoss_last_20_batches: 0.333 current_batch_time: 0.05 secs
# epoch : 25 batch_no:   60 MeanLoss_last_20_batches: 0.348 current_batch_time: 0.05 secs
# epoch : 25 batch_no:   80 MeanLoss_last_20_batches: 0.354 current_batch_time: 0.05 secs
# epoch : 25 batch_no:  100 MeanLoss_last_20_batches: 0.366 current_batch_time: 0.05 secs
# epoch : 25 batch_no:  120 MeanLoss_last_20_batches: 0.374 current_batch_time: 0.04 secs
# epoch : 25 batch_no:  140 MeanLoss_last_20_batches: 0.374 current_batch_time: 0.04 secs
# epoch : 25 batch_no:  160 MeanLoss_last_20_batches: 0.356 current_batch_time: 0.05 secs
# epoch : 25 batch_no:  180 MeanLoss_last_20_batches: 0.367 current_batch_time: 0.05 secs
# Time taken for epoch :  25  =  23.31  secs
# Epoch 25 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.5483, Accuracy: 8149/10000 (81%)
#
# epoch : 26 batch_no:   20 MeanLoss_last_20_batches: 0.371 current_batch_time: 0.04 secs
# epoch : 26 batch_no:   40 MeanLoss_last_20_batches: 0.360 current_batch_time: 0.04 secs
# epoch : 26 batch_no:   60 MeanLoss_last_20_batches: 0.383 current_batch_time: 0.04 secs
# epoch : 26 batch_no:   80 MeanLoss_last_20_batches: 0.375 current_batch_time: 0.05 secs
# epoch : 26 batch_no:  100 MeanLoss_last_20_batches: 0.335 current_batch_time: 0.04 secs
# epoch : 26 batch_no:  120 MeanLoss_last_20_batches: 0.336 current_batch_time: 0.04 secs
# epoch : 26 batch_no:  140 MeanLoss_last_20_batches: 0.346 current_batch_time: 0.04 secs
# epoch : 26 batch_no:  160 MeanLoss_last_20_batches: 0.335 current_batch_time: 0.04 secs
# epoch : 26 batch_no:  180 MeanLoss_last_20_batches: 0.381 current_batch_time: 0.05 secs
# Time taken for epoch :  26  =  22.40  secs
# Epoch 26 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.5280, Accuracy: 8265/10000 (83%)
#
# epoch : 27 batch_no:   20 MeanLoss_last_20_batches: 0.349 current_batch_time: 0.05 secs
# epoch : 27 batch_no:   40 MeanLoss_last_20_batches: 0.338 current_batch_time: 0.05 secs
# epoch : 27 batch_no:   60 MeanLoss_last_20_batches: 0.330 current_batch_time: 0.05 secs
# epoch : 27 batch_no:   80 MeanLoss_last_20_batches: 0.361 current_batch_time: 0.05 secs
# epoch : 27 batch_no:  100 MeanLoss_last_20_batches: 0.339 current_batch_time: 0.06 secs
# epoch : 27 batch_no:  120 MeanLoss_last_20_batches: 0.351 current_batch_time: 0.05 secs
# epoch : 27 batch_no:  140 MeanLoss_last_20_batches: 0.348 current_batch_time: 0.05 secs
# epoch : 27 batch_no:  160 MeanLoss_last_20_batches: 0.351 current_batch_time: 0.05 secs
# epoch : 27 batch_no:  180 MeanLoss_last_20_batches: 0.349 current_batch_time: 0.05 secs
# Time taken for epoch :  27  =  21.40  secs
# Epoch 27 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.5088, Accuracy: 8342/10000 (83%)
#
# epoch : 28 batch_no:   20 MeanLoss_last_20_batches: 0.301 current_batch_time: 0.05 secs
# epoch : 28 batch_no:   40 MeanLoss_last_20_batches: 0.325 current_batch_time: 0.05 secs
# epoch : 28 batch_no:   60 MeanLoss_last_20_batches: 0.313 current_batch_time: 0.04 secs
# epoch : 28 batch_no:   80 MeanLoss_last_20_batches: 0.330 current_batch_time: 0.05 secs
# epoch : 28 batch_no:  100 MeanLoss_last_20_batches: 0.325 current_batch_time: 0.04 secs
# epoch : 28 batch_no:  120 MeanLoss_last_20_batches: 0.320 current_batch_time: 0.05 secs
# epoch : 28 batch_no:  140 MeanLoss_last_20_batches: 0.319 current_batch_time: 0.06 secs
# epoch : 28 batch_no:  160 MeanLoss_last_20_batches: 0.308 current_batch_time: 0.05 secs
# epoch : 28 batch_no:  180 MeanLoss_last_20_batches: 0.339 current_batch_time: 0.05 secs
# Time taken for epoch :  28  =  23.48  secs
# Epoch 28 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.5598, Accuracy: 8217/10000 (82%)
#
# epoch : 29 batch_no:   20 MeanLoss_last_20_batches: 0.312 current_batch_time: 0.05 secs
# epoch : 29 batch_no:   40 MeanLoss_last_20_batches: 0.316 current_batch_time: 0.05 secs
# epoch : 29 batch_no:   60 MeanLoss_last_20_batches: 0.341 current_batch_time: 0.05 secs
# epoch : 29 batch_no:   80 MeanLoss_last_20_batches: 0.319 current_batch_time: 0.05 secs
# epoch : 29 batch_no:  100 MeanLoss_last_20_batches: 0.320 current_batch_time: 0.05 secs
# epoch : 29 batch_no:  120 MeanLoss_last_20_batches: 0.307 current_batch_time: 0.05 secs
# epoch : 29 batch_no:  140 MeanLoss_last_20_batches: 0.329 current_batch_time: 0.05 secs
# epoch : 29 batch_no:  160 MeanLoss_last_20_batches: 0.325 current_batch_time: 0.05 secs
# epoch : 29 batch_no:  180 MeanLoss_last_20_batches: 0.320 current_batch_time: 0.04 secs
# Time taken for epoch :  29  =  23.37  secs
# Epoch 29 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.5823, Accuracy: 8146/10000 (81%)
#
# epoch : 30 batch_no:   20 MeanLoss_last_20_batches: 0.312 current_batch_time: 0.04 secs
# epoch : 30 batch_no:   40 MeanLoss_last_20_batches: 0.280 current_batch_time: 0.05 secs
# epoch : 30 batch_no:   60 MeanLoss_last_20_batches: 0.314 current_batch_time: 0.04 secs
# epoch : 30 batch_no:   80 MeanLoss_last_20_batches: 0.299 current_batch_time: 0.04 secs
# epoch : 30 batch_no:  100 MeanLoss_last_20_batches: 0.315 current_batch_time: 0.05 secs
# epoch : 30 batch_no:  120 MeanLoss_last_20_batches: 0.309 current_batch_time: 0.04 secs
# epoch : 30 batch_no:  140 MeanLoss_last_20_batches: 0.303 current_batch_time: 0.05 secs
# epoch : 30 batch_no:  160 MeanLoss_last_20_batches: 0.324 current_batch_time: 0.04 secs
# epoch : 30 batch_no:  180 MeanLoss_last_20_batches: 0.330 current_batch_time: 0.04 secs
# Time taken for epoch :  30  =  21.49  secs
# Epoch 30 | Training checkpoint saved at checkpoint.pt
# Test set: Average loss: 0.5671, Accuracy: 8228/10000 (82%)

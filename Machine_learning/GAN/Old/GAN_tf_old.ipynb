# %%
# Kevin Richard

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, optimizers, losses
import time
import os
from IPython.display import display, Image
import cv2
import numpy as np
import tensorflow as tf
import random
from tensorflow.keras.preprocessing.image import array_to_img
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.models import Model

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
Train_Folder ='training/'

images = []

image_files= [f for f in os.listdir(Train_Folder) if f.endswith('.jpg')]

# Load each PNG file into the images list
for image_file in image_files:
    image_path = os.path.join(Train_Folder, image_  file)
    images.append(Image(filename=image_path))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 5
#       1 Train_Folder ='training/'
#       3 images = []
# ----> 5 image_files= [f for f in os.listdir(Train_Folder) if f.endswith('.jpg')]
#       7 # Load each PNG file into the images list
#       8 for image_file in image_files:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'training/'

# %%
display(images[5])

# %%
sketch_list = []
image_list = []

def generate_image(image_path):
    og_image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    n_image = cv2.resize(og_image, (128, 128))
    n_image[0] = n_image[0]/255.0
    n_image[1] = n_image[1]/255.0
    return n_image

def generate_outline(image_path):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    n_image = cv2.resize(image, (256, 256))
    blurred = cv2.GaussianBlur(n_image, (3, 3), 1)
    edges = cv2.Canny(blurred, 30, 60)
    inverted_edges = cv2.bitwise_not(edges)
    resized_image = cv2.resize(inverted_edges, (128, 128))
    gray_image_final = resized_image/255.0
    return gray_image_final

for image_file in image_files:
    image_path = os.path.join(Train_Folder, image_file)
    image_list.append(generate_image(image_path))
    sketch_list.append(generate_outline(image_path))

# %%
sketch_list[1].shape
# Out:
# (128, 128)

# %%
plt.figure(figsize=(12, 6))
for i in range(5):
    plt.subplot(2, 5, i + 1)
    plt.imshow(image_list[i], cmap='gray')
    plt.axis('off')
plt.show()
plt.figure(figsize=(12, 6))
for i in range(5):
    plt.subplot(2, 5, i + 1)
    plt.imshow(sketch_list[i], cmap='gray')
    plt.axis('off')
plt.show()

# %%
# display(train_list[10])

# %%
sketch_list[5].shape
# Out:
# (128, 128)

# %%
def build_generator():
    model = models.Sequential()

    # Input layer
    model.add(layers.Input(shape=(128, 128, 1)))

    model.add(layers.Conv2DTranspose(256, (4, 4), strides=1, padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(0.2))

    model.add(layers.Conv2DTranspose(128, (4, 4), strides=1, padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(0.2))

    # model.add(layers.UpSampling2D())
    model.add(layers.Conv2D(64, (3, 3), strides=1, padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(0.2))
    # model.add(layers.MaxPooling2D(pool_size=(2, 2)))

    # model.add(layers.UpSampling2D())
    model.add(layers.Conv2D(32, (3, 3), strides=1, padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(0.2))
    # model.add(layers.MaxPooling2D(pool_size=(2, 2)))

    model.add(layers.Conv2D(3, (5, 5), padding='same', activation='sigmoid'))

    return model

# %%
generator = build_generator()

# %%
generator.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_transpose_3 (Conv2D  (None, 128, 128, 256)     4352
#  Transpose)
#
#  batch_normalization_4 (Bat  (None, 128, 128, 256)     1024
#  chNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 128, 128, 256)     0
#
#  conv2d_transpose_4 (Conv2D  (None, 128, 128, 128)     524416
#  Transpose)
#
#  batch_normalization_5 (Bat  (None, 128, 128, 128)     512
#  chNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 128, 128, 128)     0
#
#  conv2d_6 (Conv2D)           (None, 128, 128, 64)      73792
#
#  batch_normalization_6 (Bat  (None, 128, 128, 64)      256
#  chNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 128, 128, 64)      0
#
#  conv2d_7 (Conv2D)           (None, 128, 128, 32)      18464
#
#  batch_normalization_7 (Bat  (None, 128, 128, 32)      128
#  chNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 128, 128, 32)      0
#
#  conv2d_8 (Conv2D)           (None, 128, 128, 3)       2403
#
# =================================================================
# Total params: 625347 (2.39 MB)
# Trainable params: 624387 (2.38 MB)
# Non-trainable params: 960 (3.75 KB)
# _________________________________________________________________

# %%
input_images = np.array(sketch_list[:4])

input_images.shape
# Out:
# (4, 128, 128)

# %%
img = generator.predict(input_images)
# Out:
# 1/1 [==============================] - 0s 136ms/step

# %%
img.shape
# Out:
# (4, 128, 128, 3)

# %%
plt.figure(figsize=(12, 6))
for i in range(img.shape[0]):
    plt.subplot(2, 5, i + 1)
    plt.imshow(img[i], cmap='gray')
    plt.axis('off')
plt.show()

# %%
img_shape = img.shape
img_shape
# Out:
# (4, 128, 128, 3)

# %%
def build_discriminator():
    model = models.Sequential()

    model.add(layers.Input(shape=(128, 128, 3)))

    model.add(layers.Conv2D(128, (5, 5), strides=1, padding='same'))
    model.add(layers.LeakyReLU(0.2))
    model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(64, (4, 4), strides=1, padding='same'))
    model.add(layers.LeakyReLU(0.2))
    model.add(layers.Dropout(0.3))
    # model.add(layers.MaxPooling2D(pool_size=(2, 2)))

    model.add(layers.Conv2D(32, (5, 5), strides=1, padding='same'))
    model.add(layers.LeakyReLU(0.2))
    model.add(layers.Dropout(0.3))

    model.add(layers.Flatten())
    model.add(layers.Dense(1, activation='sigmoid'))

    return model

# %%
discriminator = build_discriminator()

# %%
discriminator.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 128, 128, 128)     9728
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 128, 128, 128)     0
#
#  dropout_3 (Dropout)         (None, 128, 128, 128)     0
#
#  conv2d_10 (Conv2D)          (None, 128, 128, 64)      131136
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 128, 128, 64)      0
#
#  dropout_4 (Dropout)         (None, 128, 128, 64)      0
#
#  conv2d_11 (Conv2D)          (None, 128, 128, 32)      51232
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 128, 128, 32)      0
#
#  dropout_5 (Dropout)         (None, 128, 128, 32)      0
#
#  flatten_1 (Flatten)         (None, 524288)            0
#
#  dense_1 (Dense)             (None, 1)                 524289
#
# =================================================================
# Total params: 716385 (2.73 MB)
# Trainable params: 716385 (2.73 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# discriminator.compile(loss="binary_crossentropy", optimizer=optimizers.Adam(learning_rate=0.0002, beta_1=0.5))
discriminator.predict(img)
# Out:
# 1/1 [==============================] - 0s 68ms/step
# array([[0.49420425],
#        [0.4941286 ],
#        [0.49428245],
#        [0.49439362]], dtype=float32)

# %%
generator_optimizer = optimizers.Adam(learning_rate = 0.0001)
discriminator_optimizer = optimizers.Adam(learning_rate = 0.00001)
generator_loss = losses.BinaryCrossentropy()
discriminator_loss = losses.BinaryCrossentropy()

# %%
class LandscapeGAN(Model):
    def __init__(self, generator, discriminator, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.generator = generator
        self.discriminator = discriminator

    def compile(self, generator_optimizer, discriminator_optimizer, generator_loss, discriminator_loss, *args, **kwargs):
        super().compile(*args, **kwargs)
        self.generator_optimizer = generator_optimizer
        self.discriminator_optimizer = discriminator_optimizer
        self.generator_loss = generator_loss
        self.discriminator_loss = discriminator_loss

    def train_step(self, batch):
        real_images = batch
        batch_size = tf.shape(real_images)[0]

        # Assuming Y_list is either a parameter or an attribute of the class
        Y_list_2d = tf.reshape(Y_list, (tf.shape(Y_list)[0], -1))

        # Generate random indices using TensorFlow
        random_indices = tf.random.shuffle(tf.range(tf.shape(Y_list_2d)[0]))[:batch_size]
        random_values = tf.gather(Y_list, random_indices)

        fake_images = self.generator(random_values, training=False)

        with tf.GradientTape() as discriminator_tape:
            r_images = self.discriminator(real_images, training=True)
            f_images = self.discriminator(fake_images, training=True)
            rf_images = tf.concat([r_images, f_images], axis=0)

            label_rf = tf.concat([tf.zeros_like(r_images), tf.ones_like(f_images)], axis=0)

            noise_r = 0.15 * tf.random.uniform(tf.shape(r_images))
            noise_f = -0.15 * tf.random.uniform(tf.shape(f_images))

            label_rf += tf.concat([noise_r, noise_f], axis=0)

            discriminator_loss = self.discriminator_loss(label_rf, rf_images)

        discriminator_gradient = discriminator_tape.gradient(discriminator_loss, self.discriminator.trainable_variables)
        self.discriminator_optimizer.apply_gradients(zip(discriminator_gradient, self.discriminator.trainable_variables))

        with tf.GradientTape() as generator_tape:
            generated_images = self.generator(tf.random.normal((batch_size, 128, 128, 1)), training=True)
            predicted_labels = self.discriminator(generated_images, training=False)
            generator_loss = self.generator_loss(tf.zeros_like(predicted_labels), predicted_labels)

        generator_gradient = generator_tape.gradient(generator_loss, self.generator.trainable_variables)
        self.generator_optimizer.apply_gradients(zip(generator_gradient, self.generator.trainable_variables))

        return {"d_loss": discriminator_loss, "g_loss": generator_loss}

# %%
landGAN = LandscapeGAN(generator, discriminator)

# %%
landGAN.compile(generator_optimizer, discriminator_optimizer, generator_loss, discriminator_loss)

# %%
class ModelMonitor(Callback):
    def __init__(self, num_img=1):
        self.num_img = num_img
        # self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        Y_list_2d = Y_list.reshape((Y_list.shape[0], -1))
        random_indices = np.random.choice(Y_list_2d.shape[0], self.num_img, replace=False)
        random_values = Y_list[random_indices]
        # random_latent_vectors = tf.random.uniform((self.num_img, self.latent_dim,1))
        generated_images = self.model.generator(random_values)
        generated_images *= 255.0
        generated_images.numpy()
        for i in range(self.num_img):
            img = array_to_img(generated_images[i])
            img.save(os.path.join('images', f'generated_img_{epoch}_{i}.png'))

# %%
# X_list = np.array(random.sample(train_list, k=128))
X_list = np.array(image_list)

global Y_list
Y_list = np.array(sketch_list)

# XY_list = (X_list,Y_list)

# XY_list[1].shape
Y_list[1].shape
# Out:
# (128, 128)

# %%
landscapes = landGAN.fit(X_list, epochs=500, batch_size=20, callbacks=[ModelMonitor()])
# Out:
# Epoch 1/500
#  6/15 [===========>..................] - ETA: 1s - d_loss: 0.9878 - g_loss: 0.3715
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0331s vs `on_train_batch_end` time: 0.1865s). Check your callbacks.
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.9896 - g_loss: 0.3918
# Epoch 2/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 1.0545 - g_loss: 0.3748
# Epoch 3/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 1.0501 - g_loss: 0.4240
# Epoch 4/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 1.0785 - g_loss: 0.3081
# Epoch 5/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 1.0511 - g_loss: 0.2412
# Epoch 6/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 1.0118 - g_loss: 0.3220
# Epoch 7/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.9827 - g_loss: 0.4184
# Epoch 8/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.9725 - g_loss: 0.3603
# Epoch 9/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.9506 - g_loss: 0.3074
# Epoch 10/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.9610 - g_loss: 0.3193
# Epoch 11/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.9612 - g_loss: 0.3091
# Epoch 12/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.9621 - g_loss: 0.2946
# Epoch 13/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.9425 - g_loss: 0.2718
# Epoch 14/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.9090 - g_loss: 0.2712
# Epoch 15/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.9845 - g_loss: 0.2898
# Epoch 16/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.9374 - g_loss: 0.2322
# Epoch 17/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.9728 - g_loss: 0.2491
# Epoch 18/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 1.0704 - g_loss: 0.2217
# Epoch 19/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 1.0005 - g_loss: 0.2782
# Epoch 20/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.9389 - g_loss: 0.3108
# Epoch 21/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.9489 - g_loss: 0.3051
# Epoch 22/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.9377 - g_loss: 0.3275
# Epoch 23/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.9599 - g_loss: 0.3260
# Epoch 24/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 1.0220 - g_loss: 0.3294
# Epoch 25/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 1.0049 - g_loss: 0.3255
# Epoch 26/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.9522 - g_loss: 0.4846
# Epoch 27/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.9287 - g_loss: 0.5443
# Epoch 28/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.8393 - g_loss: 0.5739
# Epoch 29/500
# 15/15 [==============================] - 4s 240ms/step - d_loss: 0.8583 - g_loss: 0.4834
# Epoch 30/500
# 15/15 [==============================] - 3s 232ms/step - d_loss: 0.8200 - g_loss: 0.3203
# Epoch 31/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.8642 - g_loss: 0.3113
# Epoch 32/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.8498 - g_loss: 0.2995
# Epoch 33/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.8358 - g_loss: 0.2653
# Epoch 34/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 1.0855 - g_loss: 0.2678
# Epoch 35/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 1.1870 - g_loss: 0.2423
# Epoch 36/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 1.0339 - g_loss: 0.2873
# Epoch 37/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 1.0593 - g_loss: 0.4304
# Epoch 38/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 1.0050 - g_loss: 0.3099
# Epoch 39/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.9483 - g_loss: 0.4288
# Epoch 40/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.9116 - g_loss: 0.5519
# Epoch 41/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.9928 - g_loss: 0.4338
# Epoch 42/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.9848 - g_loss: 0.5901
# Epoch 43/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 1.1705 - g_loss: 0.2517
# Epoch 44/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 1.0130 - g_loss: 0.2495
# Epoch 45/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 1.0106 - g_loss: 0.3717
# Epoch 46/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.8843 - g_loss: 0.5041
# Epoch 47/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.9494 - g_loss: 0.4702
# Epoch 48/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.8241 - g_loss: 0.5704
# Epoch 49/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.8175 - g_loss: 0.6034
# Epoch 50/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.9024 - g_loss: 0.5551
# Epoch 51/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.8578 - g_loss: 0.6897
# Epoch 52/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7869 - g_loss: 0.7011
# Epoch 53/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7411 - g_loss: 0.7620
# Epoch 54/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7567 - g_loss: 0.6598
# Epoch 55/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.7393 - g_loss: 0.5977
# Epoch 56/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.7304 - g_loss: 0.6301
# Epoch 57/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6984 - g_loss: 0.6629
# Epoch 58/500
# 15/15 [==============================] - 3s 228ms/step - d_loss: 0.7351 - g_loss: 0.6795
# Epoch 59/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.6762 - g_loss: 0.6330
# Epoch 60/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7058 - g_loss: 0.5106
# Epoch 61/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7318 - g_loss: 0.5067
# Epoch 62/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7448 - g_loss: 0.5485
# Epoch 63/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7642 - g_loss: 0.5388
# Epoch 64/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7664 - g_loss: 0.4795
# Epoch 65/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7216 - g_loss: 0.5445
# Epoch 66/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7268 - g_loss: 0.6419
# Epoch 67/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.6980 - g_loss: 0.7187
# Epoch 68/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7309 - g_loss: 0.5438
# Epoch 69/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7418 - g_loss: 0.4298
# Epoch 70/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7676 - g_loss: 0.4267
# Epoch 71/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7862 - g_loss: 0.4564
# Epoch 72/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.8050 - g_loss: 0.5501
# Epoch 73/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.7896 - g_loss: 0.6620
# Epoch 74/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.8217 - g_loss: 0.7064
# Epoch 75/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7053 - g_loss: 0.6807
# Epoch 76/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7249 - g_loss: 0.7828
# Epoch 77/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.7329 - g_loss: 0.8757
# Epoch 78/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.7071 - g_loss: 1.0003
# Epoch 79/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.6731 - g_loss: 0.5597
# Epoch 80/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7243 - g_loss: 0.3856
# Epoch 81/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7332 - g_loss: 0.4080
# Epoch 82/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.6920 - g_loss: 0.5314
# Epoch 83/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.7169 - g_loss: 0.6034
# Epoch 84/500
# 15/15 [==============================] - 3s 228ms/step - d_loss: 0.7571 - g_loss: 0.6207
# Epoch 85/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7055 - g_loss: 0.6324
# Epoch 86/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7287 - g_loss: 0.6662
# Epoch 87/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7099 - g_loss: 0.7343
# Epoch 88/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7037 - g_loss: 0.7856
# Epoch 89/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6805 - g_loss: 0.8419
# Epoch 90/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.6999 - g_loss: 0.8937
# Epoch 91/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7343 - g_loss: 0.9076
# Epoch 92/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6999 - g_loss: 0.9134
# Epoch 93/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7263 - g_loss: 0.9609
# Epoch 94/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.7129 - g_loss: 1.1125
# Epoch 95/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7439 - g_loss: 1.1648
# Epoch 96/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7063 - g_loss: 0.4845
# Epoch 97/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7885 - g_loss: 0.4424
# Epoch 98/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6900 - g_loss: 0.7469
# Epoch 99/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7312 - g_loss: 0.9508
# Epoch 100/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7331 - g_loss: 0.7260
# Epoch 101/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7734 - g_loss: 0.5863
# Epoch 102/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.6786 - g_loss: 1.6622
# Epoch 103/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.8299 - g_loss: 2.1265
# Epoch 104/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7293 - g_loss: 0.8420
# Epoch 105/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7371 - g_loss: 1.0592
# Epoch 106/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7043 - g_loss: 1.4479
# Epoch 107/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.6926 - g_loss: 1.5754
# Epoch 108/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7043 - g_loss: 1.7038
# Epoch 109/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.6839 - g_loss: 1.7566
# Epoch 110/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7296 - g_loss: 1.6623
# Epoch 111/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7268 - g_loss: 1.5739
# Epoch 112/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7270 - g_loss: 1.6527
# Epoch 113/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7050 - g_loss: 1.7447
# Epoch 114/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.6804 - g_loss: 1.7028
# Epoch 115/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7243 - g_loss: 1.8251
# Epoch 116/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6801 - g_loss: 1.9288
# Epoch 117/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7033 - g_loss: 1.9084
# Epoch 118/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7100 - g_loss: 1.8004
# Epoch 119/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6944 - g_loss: 1.6828
# Epoch 120/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6804 - g_loss: 1.6770
# Epoch 121/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7127 - g_loss: 1.6923
# Epoch 122/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7016 - g_loss: 1.7547
# Epoch 123/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7104 - g_loss: 1.8294
# Epoch 124/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7601 - g_loss: 0.7300
# Epoch 125/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7282 - g_loss: 0.4905
# Epoch 126/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.6786 - g_loss: 0.4430
# Epoch 127/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7013 - g_loss: 0.4337
# Epoch 128/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7175 - g_loss: 0.4608
# Epoch 129/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7149 - g_loss: 0.6961
# Epoch 130/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7094 - g_loss: 1.4209
# Epoch 131/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7182 - g_loss: 1.8474
# Epoch 132/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7113 - g_loss: 1.7570
# Epoch 133/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7001 - g_loss: 1.7361
# Epoch 134/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7594 - g_loss: 1.3370
# Epoch 135/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7214 - g_loss: 1.2624
# Epoch 136/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7169 - g_loss: 2.1579
# Epoch 137/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.6988 - g_loss: 2.1288
# Epoch 138/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.7147 - g_loss: 1.8119
# Epoch 139/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.6905 - g_loss: 1.6302
# Epoch 140/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7039 - g_loss: 1.6090
# Epoch 141/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.7175 - g_loss: 1.5916
# Epoch 142/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.7356 - g_loss: 1.5462
# Epoch 143/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7081 - g_loss: 1.4908
# Epoch 144/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7631 - g_loss: 1.7005
# Epoch 145/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7272 - g_loss: 2.4180
# Epoch 146/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.7064 - g_loss: 2.3228
# Epoch 147/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.7311 - g_loss: 2.1114
# Epoch 148/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7130 - g_loss: 2.1950
# Epoch 149/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7335 - g_loss: 2.2439
# Epoch 150/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.7427 - g_loss: 2.2602
# Epoch 151/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7148 - g_loss: 2.2832
# Epoch 152/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7000 - g_loss: 2.2658
# Epoch 153/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7284 - g_loss: 2.2456
# Epoch 154/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7020 - g_loss: 2.1981
# Epoch 155/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7181 - g_loss: 2.1191
# Epoch 156/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7441 - g_loss: 2.1244
# Epoch 157/500
# 15/15 [==============================] - 3s 228ms/step - d_loss: 0.7596 - g_loss: 2.1781
# Epoch 158/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.7226 - g_loss: 2.2307
# Epoch 159/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7115 - g_loss: 2.2340
# Epoch 160/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.6930 - g_loss: 2.1827
# Epoch 161/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7292 - g_loss: 2.1124
# Epoch 162/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6872 - g_loss: 2.0730
# Epoch 163/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7320 - g_loss: 2.0971
# Epoch 164/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7081 - g_loss: 2.0757
# Epoch 165/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6893 - g_loss: 2.0370
# Epoch 166/500
# 15/15 [==============================] - 3s 228ms/step - d_loss: 0.6827 - g_loss: 2.0504
# Epoch 167/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7004 - g_loss: 2.0611
# Epoch 168/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7221 - g_loss: 2.0979
# Epoch 169/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7007 - g_loss: 2.0738
# Epoch 170/500
# 15/15 [==============================] - 3s 229ms/step - d_loss: 0.7508 - g_loss: 1.9911
# Epoch 171/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7158 - g_loss: 1.9282
# Epoch 172/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7186 - g_loss: 1.9085
# Epoch 173/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7346 - g_loss: 1.9105
# Epoch 174/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7122 - g_loss: 1.9703
# Epoch 175/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7058 - g_loss: 1.9967
# Epoch 176/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7310 - g_loss: 1.9400
# Epoch 177/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7301 - g_loss: 1.9017
# Epoch 178/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6994 - g_loss: 1.9422
# Epoch 179/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7117 - g_loss: 2.0046
# Epoch 180/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.6970 - g_loss: 2.0180
# Epoch 181/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.6842 - g_loss: 2.0328
# Epoch 182/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7311 - g_loss: 2.0421
# Epoch 183/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7161 - g_loss: 2.0325
# Epoch 184/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.6789 - g_loss: 2.0448
# Epoch 185/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7134 - g_loss: 2.0461
# Epoch 186/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.6956 - g_loss: 2.0924
# Epoch 187/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.6979 - g_loss: 2.1210
# Epoch 188/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7023 - g_loss: 2.1067
# Epoch 189/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7416 - g_loss: 2.1125
# Epoch 190/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7183 - g_loss: 2.0790
# Epoch 191/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7034 - g_loss: 1.9788
# Epoch 192/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.6955 - g_loss: 1.9530
# Epoch 193/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7113 - g_loss: 1.9877
# Epoch 194/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7162 - g_loss: 2.0277
# Epoch 195/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7059 - g_loss: 2.1382
# Epoch 196/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7008 - g_loss: 2.1167
# Epoch 197/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.6871 - g_loss: 2.1015
# Epoch 198/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.6887 - g_loss: 2.0903
# Epoch 199/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7366 - g_loss: 2.1229
# Epoch 200/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7234 - g_loss: 2.1007
# Epoch 201/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7191 - g_loss: 2.0253
# Epoch 202/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7191 - g_loss: 2.0924
# Epoch 203/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7506 - g_loss: 1.1890
# Epoch 204/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7300 - g_loss: 0.5140
# Epoch 205/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7706 - g_loss: 0.5638
# Epoch 206/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.6812 - g_loss: 1.0203
# Epoch 207/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.6811 - g_loss: 0.8013
# Epoch 208/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7328 - g_loss: 0.5878
# Epoch 209/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.6565 - g_loss: 0.5420
# Epoch 210/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.7197 - g_loss: 0.5377
# Epoch 211/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7064 - g_loss: 0.4976
# Epoch 212/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7034 - g_loss: 0.5386
# Epoch 213/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.6971 - g_loss: 0.6277
# Epoch 214/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6804 - g_loss: 0.7217
# Epoch 215/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6720 - g_loss: 0.8923
# Epoch 216/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.6857 - g_loss: 1.0341
# Epoch 217/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.6883 - g_loss: 0.9145
# Epoch 218/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7209 - g_loss: 0.8256
# Epoch 219/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7173 - g_loss: 0.9892
# Epoch 220/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7023 - g_loss: 1.4933
# Epoch 221/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.6796 - g_loss: 1.8898
# Epoch 222/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7382 - g_loss: 1.6094
# Epoch 223/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7476 - g_loss: 0.6942
# Epoch 224/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7306 - g_loss: 1.7165
# Epoch 225/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6701 - g_loss: 2.4489
# Epoch 226/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.6844 - g_loss: 2.2252
# Epoch 227/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.6924 - g_loss: 2.0196
# Epoch 228/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7370 - g_loss: 2.0728
# Epoch 229/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6785 - g_loss: 2.1641
# Epoch 230/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7282 - g_loss: 2.1869
# Epoch 231/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7066 - g_loss: 2.1807
# Epoch 232/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7017 - g_loss: 2.1822
# Epoch 233/500
# 15/15 [==============================] - 3s 222ms/step - d_loss: 0.7042 - g_loss: 2.1753
# Epoch 234/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7101 - g_loss: 2.1782
# Epoch 235/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7130 - g_loss: 2.2164
# Epoch 236/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7377 - g_loss: 2.1807
# Epoch 237/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.6929 - g_loss: 2.1805
# Epoch 238/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7446 - g_loss: 2.1733
# Epoch 239/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7088 - g_loss: 2.1267
# Epoch 240/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7150 - g_loss: 2.1598
# Epoch 241/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6906 - g_loss: 2.1746
# Epoch 242/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7178 - g_loss: 2.1611
# Epoch 243/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7225 - g_loss: 2.0610
# Epoch 244/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7227 - g_loss: 1.9950
# Epoch 245/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7302 - g_loss: 2.0155
# Epoch 246/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7440 - g_loss: 1.9385
# Epoch 247/500
# 15/15 [==============================] - 3s 230ms/step - d_loss: 0.7131 - g_loss: 1.8884
# Epoch 248/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7570 - g_loss: 1.9249
# Epoch 249/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7102 - g_loss: 1.9351
# Epoch 250/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7269 - g_loss: 1.9243
# Epoch 251/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7474 - g_loss: 1.8845
# Epoch 252/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.6647 - g_loss: 1.8329
# Epoch 253/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.6891 - g_loss: 1.8244
# Epoch 254/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7479 - g_loss: 1.8641
# Epoch 255/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7436 - g_loss: 1.8702
# Epoch 256/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.6950 - g_loss: 1.8467
# Epoch 257/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7231 - g_loss: 1.8789
# Epoch 258/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7009 - g_loss: 1.9577
# Epoch 259/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.6947 - g_loss: 1.9838
# Epoch 260/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.6930 - g_loss: 2.0018
# Epoch 261/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6818 - g_loss: 2.0443
# Epoch 262/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7291 - g_loss: 2.0735
# Epoch 263/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7113 - g_loss: 2.0771
# Epoch 264/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7467 - g_loss: 2.0731
# Epoch 265/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7118 - g_loss: 2.0772
# Epoch 266/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.6723 - g_loss: 2.0761
# Epoch 267/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6794 - g_loss: 2.0571
# Epoch 268/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7284 - g_loss: 2.0300
# Epoch 269/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7451 - g_loss: 2.0800
# Epoch 270/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7139 - g_loss: 2.0788
# Epoch 271/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6759 - g_loss: 2.0414
# Epoch 272/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7107 - g_loss: 2.0871
# Epoch 273/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7125 - g_loss: 2.0929
# Epoch 274/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7150 - g_loss: 2.0473
# Epoch 275/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7113 - g_loss: 2.0494
# Epoch 276/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6975 - g_loss: 2.0902
# Epoch 277/500
# 15/15 [==============================] - 3s 228ms/step - d_loss: 0.7063 - g_loss: 2.0959
# Epoch 278/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7206 - g_loss: 2.0536
# Epoch 279/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7156 - g_loss: 2.0210
# Epoch 280/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7045 - g_loss: 2.0643
# Epoch 281/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.6757 - g_loss: 2.0257
# Epoch 282/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7363 - g_loss: 1.9214
# Epoch 283/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7094 - g_loss: 1.9357
# Epoch 284/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7299 - g_loss: 2.0231
# Epoch 285/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7048 - g_loss: 2.0454
# Epoch 286/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7002 - g_loss: 2.0868
# Epoch 287/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7020 - g_loss: 2.1262
# Epoch 288/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7017 - g_loss: 2.0494
# Epoch 289/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7177 - g_loss: 2.0459
# Epoch 290/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7489 - g_loss: 2.1080
# Epoch 291/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7193 - g_loss: 2.0452
# Epoch 292/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7195 - g_loss: 2.0674
# Epoch 293/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7053 - g_loss: 2.0800
# Epoch 294/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7084 - g_loss: 2.1110
# Epoch 295/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7354 - g_loss: 1.9748
# Epoch 296/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7146 - g_loss: 1.9582
# Epoch 297/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7254 - g_loss: 2.0722
# Epoch 298/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6850 - g_loss: 2.0590
# Epoch 299/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7223 - g_loss: 2.0685
# Epoch 300/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.6663 - g_loss: 2.0773
# Epoch 301/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.6837 - g_loss: 2.0825
# Epoch 302/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7051 - g_loss: 2.0338
# Epoch 303/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6895 - g_loss: 2.0867
# Epoch 304/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7278 - g_loss: 2.0411
# Epoch 305/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7200 - g_loss: 1.9976
# Epoch 306/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7059 - g_loss: 2.0956
# Epoch 307/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7016 - g_loss: 2.1100
# Epoch 308/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7314 - g_loss: 1.9973
# Epoch 309/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7186 - g_loss: 2.0231
# Epoch 310/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7086 - g_loss: 2.0313
# Epoch 311/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7095 - g_loss: 2.0093
# Epoch 312/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.6869 - g_loss: 2.0246
# Epoch 313/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.6745 - g_loss: 2.0373
# Epoch 314/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7065 - g_loss: 2.0078
# Epoch 315/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.6922 - g_loss: 2.0719
# Epoch 316/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.6996 - g_loss: 2.0768
# Epoch 317/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7000 - g_loss: 2.0553
# Epoch 318/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7086 - g_loss: 2.0419
# Epoch 319/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6735 - g_loss: 2.0640
# Epoch 320/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.6948 - g_loss: 2.1283
# Epoch 321/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7281 - g_loss: 2.1342
# Epoch 322/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7404 - g_loss: 2.0647
# Epoch 323/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7137 - g_loss: 2.0303
# Epoch 324/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7075 - g_loss: 2.0977
# Epoch 325/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7107 - g_loss: 2.0212
# Epoch 326/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.6902 - g_loss: 1.9947
# Epoch 327/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7159 - g_loss: 2.0294
# Epoch 328/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7278 - g_loss: 2.0729
# Epoch 329/500
# 15/15 [==============================] - 3s 229ms/step - d_loss: 0.6989 - g_loss: 2.0645
# Epoch 330/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7039 - g_loss: 2.0512
# Epoch 331/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7106 - g_loss: 2.1200
# Epoch 332/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6885 - g_loss: 2.0945
# Epoch 333/500
# 15/15 [==============================] - 3s 228ms/step - d_loss: 0.7318 - g_loss: 2.0790
# Epoch 334/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7360 - g_loss: 2.0583
# Epoch 335/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7159 - g_loss: 2.0266
# Epoch 336/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7331 - g_loss: 2.0162
# Epoch 337/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.6616 - g_loss: 2.0631
# Epoch 338/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.6879 - g_loss: 2.0674
# Epoch 339/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7071 - g_loss: 2.1085
# Epoch 340/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7159 - g_loss: 2.0928
# Epoch 341/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7170 - g_loss: 2.0635
# Epoch 342/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7176 - g_loss: 2.0729
# Epoch 343/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7146 - g_loss: 2.1293
# Epoch 344/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7223 - g_loss: 2.0378
# Epoch 345/500
# 15/15 [==============================] - 3s 228ms/step - d_loss: 0.7031 - g_loss: 2.0303
# Epoch 346/500
# 15/15 [==============================] - 3s 228ms/step - d_loss: 0.7493 - g_loss: 2.1008
# Epoch 347/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7287 - g_loss: 2.0665
# Epoch 348/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7029 - g_loss: 2.1184
# Epoch 349/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7204 - g_loss: 2.0967
# Epoch 350/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7039 - g_loss: 2.0658
# Epoch 351/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7507 - g_loss: 2.0416
# Epoch 352/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7176 - g_loss: 1.9737
# Epoch 353/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7314 - g_loss: 2.0249
# Epoch 354/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7355 - g_loss: 2.0724
# Epoch 355/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7201 - g_loss: 2.0219
# Epoch 356/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6867 - g_loss: 2.0705
# Epoch 357/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.6880 - g_loss: 2.0549
# Epoch 358/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7249 - g_loss: 2.0225
# Epoch 359/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.6907 - g_loss: 2.0310
# Epoch 360/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7052 - g_loss: 2.0255
# Epoch 361/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7194 - g_loss: 2.0542
# Epoch 362/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7382 - g_loss: 2.0829
# Epoch 363/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7215 - g_loss: 2.0986
# Epoch 364/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7436 - g_loss: 2.1324
# Epoch 365/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7159 - g_loss: 2.0828
# Epoch 366/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7066 - g_loss: 2.0607
# Epoch 367/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7187 - g_loss: 2.0820
# Epoch 368/500
# 15/15 [==============================] - 3s 228ms/step - d_loss: 0.7191 - g_loss: 2.1006
# Epoch 369/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7516 - g_loss: 2.0412
# Epoch 370/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7126 - g_loss: 2.0396
# Epoch 371/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.6784 - g_loss: 2.1300
# Epoch 372/500
# 15/15 [==============================] - 3s 228ms/step - d_loss: 0.7127 - g_loss: 2.1038
# Epoch 373/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7188 - g_loss: 2.0901
# Epoch 374/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.6739 - g_loss: 2.1405
# Epoch 375/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7127 - g_loss: 2.0441
# Epoch 376/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7006 - g_loss: 2.1321
# Epoch 377/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6967 - g_loss: 2.1295
# Epoch 378/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7404 - g_loss: 2.0973
# Epoch 379/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7078 - g_loss: 1.9926
# Epoch 380/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7092 - g_loss: 2.1218
# Epoch 381/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7387 - g_loss: 1.9944
# Epoch 382/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7027 - g_loss: 1.9804
# Epoch 383/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7159 - g_loss: 2.1199
# Epoch 384/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.6850 - g_loss: 2.0592
# Epoch 385/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7072 - g_loss: 2.0345
# Epoch 386/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6962 - g_loss: 2.0417
# Epoch 387/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7114 - g_loss: 2.0438
# Epoch 388/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7234 - g_loss: 2.0591
# Epoch 389/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7005 - g_loss: 2.0658
# Epoch 390/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.6724 - g_loss: 2.0412
# Epoch 391/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7004 - g_loss: 2.0531
# Epoch 392/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7196 - g_loss: 2.0557
# Epoch 393/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.6935 - g_loss: 2.0772
# Epoch 394/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7267 - g_loss: 2.0024
# Epoch 395/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7028 - g_loss: 2.0441
# Epoch 396/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7179 - g_loss: 1.9900
# Epoch 397/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.6968 - g_loss: 2.0190
# Epoch 398/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7215 - g_loss: 2.0989
# Epoch 399/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6879 - g_loss: 2.0893
# Epoch 400/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7120 - g_loss: 2.0455
# Epoch 401/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7160 - g_loss: 2.0677
# Epoch 402/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.6950 - g_loss: 2.0622
# Epoch 403/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7360 - g_loss: 2.1033
# Epoch 404/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7248 - g_loss: 2.0223
# Epoch 405/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7135 - g_loss: 2.0955
# Epoch 406/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.6841 - g_loss: 2.0841
# Epoch 407/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7258 - g_loss: 2.0404
# Epoch 408/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7290 - g_loss: 2.0578
# Epoch 409/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7054 - g_loss: 2.0835
# Epoch 410/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7091 - g_loss: 2.1054
# Epoch 411/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7143 - g_loss: 2.0235
# Epoch 412/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7166 - g_loss: 2.0873
# Epoch 413/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7101 - g_loss: 2.0836
# Epoch 414/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7029 - g_loss: 2.0718
# Epoch 415/500
# 15/15 [==============================] - 3s 229ms/step - d_loss: 0.7219 - g_loss: 2.1235
# Epoch 416/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7254 - g_loss: 2.0402
# Epoch 417/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7002 - g_loss: 2.0257
# Epoch 418/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7610 - g_loss: 2.0755
# Epoch 419/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7202 - g_loss: 2.0737
# Epoch 420/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7283 - g_loss: 2.0664
# Epoch 421/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7092 - g_loss: 2.0506
# Epoch 422/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7258 - g_loss: 1.9813
# Epoch 423/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7400 - g_loss: 1.8989
# Epoch 424/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.6920 - g_loss: 2.0940
# Epoch 425/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.6912 - g_loss: 2.0639
# Epoch 426/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7069 - g_loss: 2.1019
# Epoch 427/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7041 - g_loss: 1.9992
# Epoch 428/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.6781 - g_loss: 2.0637
# Epoch 429/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6855 - g_loss: 2.1181
# Epoch 430/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7181 - g_loss: 2.0477
# Epoch 431/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7001 - g_loss: 2.0416
# Epoch 432/500
# 15/15 [==============================] - 3s 228ms/step - d_loss: 0.7055 - g_loss: 2.0500
# Epoch 433/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7210 - g_loss: 2.0469
# Epoch 434/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7211 - g_loss: 2.0455
# Epoch 435/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7107 - g_loss: 1.9834
# Epoch 436/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7423 - g_loss: 2.0482
# Epoch 437/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.6963 - g_loss: 1.8862
# Epoch 438/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7033 - g_loss: 1.9385
# Epoch 439/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6886 - g_loss: 2.0785
# Epoch 440/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7204 - g_loss: 2.0031
# Epoch 441/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.6692 - g_loss: 2.0852
# Epoch 442/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6972 - g_loss: 2.0578
# Epoch 443/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.6955 - g_loss: 2.0969
# Epoch 444/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7158 - g_loss: 2.1011
# Epoch 445/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7002 - g_loss: 2.0610
# Epoch 446/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7471 - g_loss: 2.0519
# Epoch 447/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7205 - g_loss: 2.0196
# Epoch 448/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6968 - g_loss: 2.0344
# Epoch 449/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.6919 - g_loss: 2.1214
# Epoch 450/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6589 - g_loss: 2.1207
# Epoch 451/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7250 - g_loss: 2.1386
# Epoch 452/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7514 - g_loss: 2.0516
# Epoch 453/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7246 - g_loss: 2.0591
# Epoch 454/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7167 - g_loss: 2.0609
# Epoch 455/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7473 - g_loss: 1.9550
# Epoch 456/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.6891 - g_loss: 2.1105
# Epoch 457/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7448 - g_loss: 2.0299
# Epoch 458/500
# 15/15 [==============================] - 3s 228ms/step - d_loss: 0.6933 - g_loss: 2.0776
# Epoch 459/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7154 - g_loss: 2.0837
# Epoch 460/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7220 - g_loss: 1.9884
# Epoch 461/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6923 - g_loss: 2.1062
# Epoch 462/500
# 15/15 [==============================] - 3s 227ms/step - d_loss: 0.7319 - g_loss: 2.0814
# Epoch 463/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7020 - g_loss: 2.1380
# Epoch 464/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7097 - g_loss: 2.0128
# Epoch 465/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7087 - g_loss: 2.0203
# Epoch 466/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7347 - g_loss: 2.0356
# Epoch 467/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.6990 - g_loss: 2.0172
# Epoch 468/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7025 - g_loss: 2.0645
# Epoch 469/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7330 - g_loss: 2.0408
# Epoch 470/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7157 - g_loss: 2.0288
# Epoch 471/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7223 - g_loss: 2.1530
# Epoch 472/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7077 - g_loss: 1.9655
# Epoch 473/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7445 - g_loss: 2.0833
# Epoch 474/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7232 - g_loss: 2.0948
# Epoch 475/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.6977 - g_loss: 2.0612
# Epoch 476/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.6789 - g_loss: 2.0453
# Epoch 477/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7182 - g_loss: 2.0547
# Epoch 478/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7255 - g_loss: 2.0986
# Epoch 479/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7034 - g_loss: 2.0571
# Epoch 480/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6974 - g_loss: 2.1259
# Epoch 481/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7280 - g_loss: 1.9622
# Epoch 482/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7074 - g_loss: 2.1558
# Epoch 483/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7270 - g_loss: 2.0013
# Epoch 484/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7180 - g_loss: 2.0779
# Epoch 485/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.6987 - g_loss: 2.0666
# Epoch 486/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7325 - g_loss: 1.9947
# Epoch 487/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7165 - g_loss: 2.0353
# Epoch 488/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7015 - g_loss: 2.1118
# Epoch 489/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7758 - g_loss: 2.0475
# Epoch 490/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.6970 - g_loss: 2.0272
# Epoch 491/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7071 - g_loss: 2.1038
# Epoch 492/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.7367 - g_loss: 2.1090
# Epoch 493/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7366 - g_loss: 2.0517
# Epoch 494/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.7147 - g_loss: 2.0582
# Epoch 495/500
# 15/15 [==============================] - 3s 223ms/step - d_loss: 0.7413 - g_loss: 2.0845
# Epoch 496/500
# 15/15 [==============================] - 3s 225ms/step - d_loss: 0.6735 - g_loss: 2.1188
# Epoch 497/500
# 15/15 [==============================] - 3s 226ms/step - d_loss: 0.6826 - g_loss: 2.1236
# Epoch 498/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6867 - g_loss: 1.9782
# Epoch 499/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.7103 - g_loss: 2.1380
# Epoch 500/500
# 15/15 [==============================] - 3s 224ms/step - d_loss: 0.6927 - g_loss: 2.0220

# %%
plt.suptitle('Loss')
plt.plot(landscapes.history['d_loss'], label='d_loss')
plt.plot(landscapes.history['g_loss'], label='g_loss')
plt.legend()
plt.show()

# %%
generated_images = generator.predict(input_images)

num_images = len(generated_images)

for i in range(num_images):
    plt.subplot(1, num_images, i+1)
    plt.imshow(generated_images[i])
    plt.axis("off")
plt.show()
# Out:
# 1/1 [==============================] - 0s 18ms/step

# %%
# import shutil

# shutil.rmtree('images')
# os.makedirs('images', exist_ok=True)

# %%
# generator.save('generator.h5')
# discriminator.save('discriminator.h5')

# %%
# # Save the generator model in the native Keras format
# generator.save('generator_model.keras')

# # Save the discriminator model in the native Keras format
# discriminator.save('discriminator_model.keras')

# %%
# from keras.models import load_model

# # Load the generator model
# loaded_generator = load_model('generator_model.h5')

# # Load the discriminator model
# loaded_discriminator = load_model('discriminator_model.h5')
